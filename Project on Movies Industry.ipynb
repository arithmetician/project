# %% [markdown]
# > **Welcome Back !!!**: Welcome to the Exploratory Data Analysis project!
#
# # Project: Exploratory  of Data Analysis on Movies Industry by Adepoju Ibrahim
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('tmdb-movies.csv')

# %%
data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
data.rename(columns = {'original_title': 'Title'})
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                               Title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
data['id']
# Out:
# 0        135397
# 1         76341
# 2        262500
# 3        140607
# 4        168259
#           ...
# 10861        21
# 10862     20379
# 10863     39768
# 10864     21449
# 10865     22293
# Name: id, Length: 10866, dtype: int64

# %%
type(data["id"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Rename some columns

# %%
data.rename(columns = {'original_title':'Title'})
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                               Title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
data.rename(columns = {'cast':'Cast'})
data.rename(columns = {'budget':'Budget'})
data.rename(columns = {'revenue':'Revenue'})
# Out:
#            id    imdb_id  popularity     budget     Revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
data.rename(columns = {'cast':'Cast'})
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
data.rename(columns = {'original_title':'Title'})
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                               Title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
data = data.rename(columns = {'original_title':'Title'})

# %% [markdown]
# # Q1:- is there any title for the new movies?

# %%
data.Title.value_counts()
# Out:
# Hamlet                      4
# The Black Hole              3
# Shelter                     3
# The Three Musketeers        3
# Julia                       3
#                            ..
# Beneath the Darkness        1
# The Veteran                 1
# African Cats                1
# Your Sister's Sister        1
# Manos: The Hands of Fate    1
# Name: Title, Length: 10571, dtype: int64

# %%
data.query('Title in["African Cats","The Hands of Fate"]')
# Out:
#          id    imdb_id  popularity  budget   revenue         Title  \
# 3638  57586  tt1223236    0.413573       0  15240456  African Cats
#
#                    cast                                        homepage  \
# 3638  Samuel L. Jackson  http://disney.go.com/disneynature/africancats/
#
#                                director tagline  ...  \
# 3638  Keith Scholey|Alastair Fothergill     NaN  ...
#
#                                                overview runtime  \
# 3638  African Cats captures the real-life love, humo...      89
#
#                             genres production_companies release_date  \
# 3638  Documentary|Family|Adventure         Disneynature      4/22/11
#
#      vote_count  vote_average  release_year  budget_adj   revenue_adj
# 3638         55           7.0          2011         0.0  1.477407e+07
#
# [1 rows x 21 columns]

# %%
data.Title.unique()
# Out:
# array(['Jurassic World', 'Mad Max: Fury Road', 'Insurgent', ...,
#        'Beregis Avtomobilya', "What's Up, Tiger Lily?",
#        'Manos: The Hands of Fate'], dtype=object)

# %%
data.Title.nunique()
# Out:
# 10571

# %% [markdown]
# # Q2:- is there a certain movies(horror,comendy) associated with high popularity?

# %%
data['popularity'].unique()
# Out:
# array([32.985763, 28.419936, 13.112507, ...,  0.065141,  0.064317,
#         0.035919])

# %% [markdown]
# # who is the cast receives the height movies?

# %%
data['cast']
# Out:
# 0        Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1        Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2        Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3        Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4        Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#                                ...
# 10861    Michael Hynson|Robert August|Lord 'Tally Ho' B...
# 10862    James Garner|Eva Marie Saint|Yves Montand|Tosh...
# 10863    Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...
# 10864    Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...
# 10865    Harold P. Warren|Tom Neyman|John Reynolds|Dian...
# Name: cast, Length: 10866, dtype: object

# %%
data['cast'].describe()
# Out:
# count          10790
# unique         10719
# top       Louis C.K.
# freq               6
# Name: cast, dtype: object

# %%
bin_edges = [5000,7000,10865]
bin_names = ['low','medium','high']

# %%
data.groupby('cast')['budget'].mean()
# Out:
# cast
# "Weird Al" Yankovic|Victoria Jackson|Michael Richards|David Bowe|Fran Drescher                                    5000000.0
# 50 Cent|Forest Whitaker|Robert De Niro|Ryan O'Nan|Matt Gerald                                                    11000000.0
# 50 Cent|Joy Bryant|Adewale Akinnuoye-Agbaje|Omar Benson Miller|Terrence Howard                                   40000000.0
# 50 Cent|Ryan Phillippe|Bruce Willis|James Remar|Randy Couture                                                    20000000.0
# 50 Cent|Tamer Hassan|Danny Dyer|Blake Ritson|EsmÃ© Bianco                                                               0.0
#                                                                                                                     ...
# Ã“lafur Darri Ã“lafsson|JÃ³hann G. JÃ³hannsson|Thora Bjorg Helga|TheodÃ³r JÃºlÃ­usson|MarÃ­a SigurÃ°ardÃ³ttir     3000000.0
# ...

# %%
data.budget.median()
# Out:
# 0.0

# %%
 high = data.query('budget >= 1500000')

# %%
data.query('budget < 70000')
# Out:
#            id    imdb_id  popularity  budget   revenue  \
# 30     280996  tt3168230    3.927333       0  29355203
# 36     339527  tt1291570    3.358321       0  22354572
# 72     284289  tt2911668    2.272044       0     45895
# 74     347096  tt3478232    2.165433       0         0
# 75     308369  tt2582496    2.141506       0         0
# ...       ...        ...         ...     ...       ...
# 10861      21  tt0060371    0.080598       0         0
# 10862   20379  tt0060472    0.065543       0         0
# 10863   39768  tt0060161    0.065141       0         0
# 10864   21449  tt0061177    0.064317       0         0
# 10865   22293  tt0060666    0.035919   19000         0
#
#                                 Title  \
# 30                         Mr. Holmes
# 36                             Solace
# 72                   Beyond the Reach
# 74             Mythica: The Darkspore
# 75     Me and Earl and the Dying Girl
# ...                               ...
# ...

# %%
data.query('budget < 70000')
# Out:
#            id    imdb_id  popularity  budget   revenue  \
# 30     280996  tt3168230    3.927333       0  29355203
# 36     339527  tt1291570    3.358321       0  22354572
# 72     284289  tt2911668    2.272044       0     45895
# 74     347096  tt3478232    2.165433       0         0
# 75     308369  tt2582496    2.141506       0         0
# ...       ...        ...         ...     ...       ...
# 10861      21  tt0060371    0.080598       0         0
# 10862   20379  tt0060472    0.065543       0         0
# 10863   39768  tt0060161    0.065141       0         0
# 10864   21449  tt0061177    0.064317       0         0
# 10865   22293  tt0060666    0.035919   19000         0
#
#                                 Title  \
# 30                         Mr. Holmes
# 36                             Solace
# 72                   Beyond the Reach
# 74             Mythica: The Darkspore
# 75     Me and Earl and the Dying Girl
# ...                               ...
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'Title', 'cast',
#        'homepage', 'director', 'tagline', 'keywords', 'overview', 'runtime',
#        'genres', 'production_companies', 'release_date', 'vote_count',
#        'vote_average', 'release_year', 'budget_adj', 'revenue_adj'],
#       dtype='object')

# %%
from matplotlib import pyplot as plt

# %%
data1 = data[data.popularity == "popularity"]
plt.plot(data.revenue,data.popularity)
plt.plot(data.popularity,data.budget)
plt.xlabel('popularity')
plt.ylabel('budget')
plt.title('Graph of popularity against Budget')
plt.legend(['popularity','budget'])
plt.show()

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'Title', 'cast',
#        'homepage', 'director', 'tagline', 'keywords', 'overview', 'runtime',
#        'genres', 'production_companies', 'release_date', 'vote_count',
#        'vote_average', 'release_year', 'budget_adj', 'revenue_adj'],
#       dtype='object')

# %%
type(data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
#Report i have go through several trainning before building this portfolio.
#I ensure i analysis my codes base on people question in the movies indusrty.

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# > **Tip**: In this section of the report, provide a brief introduction to the dataset you've selected for analysis. At the end of this section, describe the questions that you plan on exploring over the course of the report. Try to build your report around the analysis of at least one dependent variable and three independent variables.
# >
# > If you haven't yet selected and downloaded your data, make sure you do that first before coming back here. If you're not sure what questions to ask right now, then make sure you familiarize yourself with the variables and the dataset context for ideas of what to explore.

# %%
# I use pandas,numpy,seaborn and matpolitlib modulus to execuate my project and very easy for me.

# %%
# Use this cell to set up import statements for all of the packages that you
#   plan to use.

# Remember to include a 'magic word' so that your visualizations are plotted
#   inline with the notebook. See this page for more:
#   http://ipython.readthedocs.io/en/stable/interactive/magics.html

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# > **Tip**: In this section of the report, you will load in the data, check for cleanliness, and then trim and clean your dataset for analysis. Make sure that you document your steps carefully and justify your cleaning decisions.
#
# ### General Properties

# %% [markdown]
# # Renaming some columns

# %%
data.rename(columns = {'popularity':'Popularity'}, inplace = True)

# %%
data
# Out:
#            id    imdb_id  Popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                               Title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
data.rename(columns = {'cast':'Cast'}, inplace = True)

# %%
data
# Out:
#            id    imdb_id  Popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                               Title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
data.rename(columns = {'revenue':'Revenue'}, inplace = True)

# %%
pd.concat([data.vote_count,data.vote_average],axis = 0)
# Out:
# 0        5562.0
# 1        6185.0
# 2        2480.0
# 3        5292.0
# 4        2947.0
#           ...
# 10861       7.4
# 10862       5.7
# 10863       6.5
# 10864       5.4
# 10865       1.5
# Length: 21732, dtype: float64

# %%
pd.concat([data.vote_count,data.vote_average],axis = 1)
# Out:
#        vote_count  vote_average
# 0            5562           6.5
# 1            6185           7.1
# 2            2480           6.3
# 3            5292           7.5
# 4            2947           7.3
# ...           ...           ...
# 10861          11           7.4
# 10862          20           5.7
# 10863          11           6.5
# 10864          22           5.4
# 10865          15           1.5
#
# [10866 rows x 2 columns]

# %%
pd.concat([data.vote_count,data.vote_average],axis = 0).mean()
# Out:
# 111.68233480581536

# %%
data3 = pd.concat([data.vote_count,data.vote_average],axis = 1)

# %%
data3
# Out:
#        vote_count  vote_average
# 0            5562           6.5
# 1            6185           7.1
# 2            2480           6.3
# 3            5292           7.5
# 4            2947           7.3
# ...           ...           ...
# 10861          11           7.4
# 10862          20           5.7
# 10863          11           6.5
# 10864          22           5.4
# 10865          15           1.5
#
# [10866 rows x 2 columns]

# %%
data3.to_csv('Data.csv',index = False)

# %%
data3.head()
# Out:
#    vote_count  vote_average
# 0        5562           6.5
# 1        6185           7.1
# 2        2480           6.3
# 3        5292           7.5
# 4        2947           7.3

# %%
Data1 = pd.concat([data.Title,data.budget],axis = 1)

# %%
Data1
# Out:
#                               Title     budget
# 0                    Jurassic World  150000000
# 1                Mad Max: Fury Road  150000000
# 2                         Insurgent  110000000
# 3      Star Wars: The Force Awakens  200000000
# 4                         Furious 7  190000000
# ...                             ...        ...
# 10861            The Endless Summer          0
# 10862                    Grand Prix          0
# 10863           Beregis Avtomobilya          0
# 10864        What's Up, Tiger Lily?          0
# 10865      Manos: The Hands of Fate      19000
#
# [10866 rows x 2 columns]

# %%
Data1.to_csv('ade.csv',index = False)

# %%
Data1.head()
# Out:
#                           Title     budget
# 0                Jurassic World  150000000
# 1            Mad Max: Fury Road  150000000
# 2                     Insurgent  110000000
# 3  Star Wars: The Force Awakens  200000000
# 4                     Furious 7  190000000

# %%
# I print out Data.csv and ade.csv was extracted from my main data frame to be explorary in the next frame of my project.

# %%
# Load your data and print out a few lines. Perform operations to inspect data
#   types and look for instances of missing or possibly errant data.

# %% [markdown]
# > **Tip**: You should _not_ perform too many operations in each cell. Create cells freely to explore your data. One option that you can take with this project is to do a lot of explorations in an initial notebook. These don't have to be organized, but make sure you use enough comments to understand the purpose of each code cell. Then, after you're done with your analysis, create a duplicate notebook where you will trim the excess and organize your steps so that you have a flowing, cohesive report.
#
#
# ## A well prepared data !!!

# %%
Data = pd.read_csv('Data.csv')

# %%
ade = pd.read_csv('ade.csv')

# %%
Data.shape[0]
# Out:
# 10866

# %%
ade.shape[0]
# Out:
# 10866

# %%
Data['vote_count'] = np.repeat('vote',Data.shape[0])

# %%
ade['budget'] = np.repeat('budget',ade.shape[0])

# %%
Data
# Out:
#       vote_count  vote_average
# 0           vote           6.5
# 1           vote           7.1
# 2           vote           6.3
# 3           vote           7.5
# 4           vote           7.3
# ...          ...           ...
# 10861       vote           7.4
# 10862       vote           5.7
# 10863       vote           6.5
# 10864       vote           5.4
# 10865       vote           1.5
#
# [10866 rows x 2 columns]

# %%
ade
# Out:
#                               Title  budget
# 0                    Jurassic World  budget
# 1                Mad Max: Fury Road  budget
# 2                         Insurgent  budget
# 3      Star Wars: The Force Awakens  budget
# 4                         Furious 7  budget
# ...                             ...     ...
# 10861            The Endless Summer  budget
# 10862                    Grand Prix  budget
# 10863           Beregis Avtomobilya  budget
# 10864        What's Up, Tiger Lily?  budget
# 10865      Manos: The Hands of Fate  budget
#
# [10866 rows x 2 columns]

# %%
#combined the 2 dataset together.

# %%
pd.concat([Data,ade],axis = 0)
# Out:
#       vote_count  vote_average                     Title  budget
# 0           vote           6.5                       NaN     NaN
# 1           vote           7.1                       NaN     NaN
# 2           vote           6.3                       NaN     NaN
# 3           vote           7.5                       NaN     NaN
# 4           vote           7.3                       NaN     NaN
# ...          ...           ...                       ...     ...
# 10861        NaN           NaN        The Endless Summer  budget
# 10862        NaN           NaN                Grand Prix  budget
# 10863        NaN           NaN       Beregis Avtomobilya  budget
# 10864        NaN           NaN    What's Up, Tiger Lily?  budget
# 10865        NaN           NaN  Manos: The Hands of Fate  budget
#
# [21732 rows x 4 columns]

# %%
#find the missing value

# %%
master = pd.concat([Data,ade],axis = 0)

# %%
master
# Out:
#       vote_count  vote_average                     Title  budget
# 0           vote           6.5                       NaN     NaN
# 1           vote           7.1                       NaN     NaN
# 2           vote           6.3                       NaN     NaN
# 3           vote           7.5                       NaN     NaN
# 4           vote           7.3                       NaN     NaN
# ...          ...           ...                       ...     ...
# 10861        NaN           NaN        The Endless Summer  budget
# 10862        NaN           NaN                Grand Prix  budget
# 10863        NaN           NaN       Beregis Avtomobilya  budget
# 10864        NaN           NaN    What's Up, Tiger Lily?  budget
# 10865        NaN           NaN  Manos: The Hands of Fate  budget
#
# [21732 rows x 4 columns]

# %%
master.to_csv('master.csv', index = False)

# %%
master.head()
# Out:
#   vote_count  vote_average Title budget
# 0       vote           6.5   NaN    NaN
# 1       vote           7.1   NaN    NaN
# 2       vote           6.3   NaN    NaN
# 3       vote           7.5   NaN    NaN
# 4       vote           7.3   NaN    NaN

# %%
# After discussing the structure of the data and any problems that need to be
#   cleaned, perform those cleaning steps in the second part of this section.

# %% [markdown]
# # <a id='eda'></a>
# ## Exploratory Data Analysis
#
# > **Tip**: Now that you've trimmed and cleaned your data, you're ready to move on to exploration. Compute statistics and create visualizations with the goal of addressing the research questions that you posed in the Introduction section. It is recommended that you be systematic with your approach. Look at one variable at a time, and then follow it up by looking at relationships between variables.
#
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data['vote_count']
# Out:
# 0        vote
# 1        vote
# 2        vote
# 3        vote
# 4        vote
#          ...
# 10861    vote
# 10862    vote
# 10863    vote
# 10864    vote
# 10865    vote
# Name: vote_count, Length: 10866, dtype: object

# %%
data3.head().plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.histplot(data = data3.head()['vote_count'])
# Out:
# <AxesSubplot:xlabel='vote_count', ylabel='Count'>

# %% [markdown]
# # Revenue against bugdet

# %%
master['vote_count']
# Out:
# 0        vote
# 1        vote
# 2        vote
# 3        vote
# 4        vote
#          ...
# 10861     NaN
# 10862     NaN
# 10863     NaN
# 10864     NaN
# 10865     NaN
# Name: vote_count, Length: 21732, dtype: object

# %%
data['Revenue']
# Out:
# 0        1513528810
# 1         378436354
# 2         295238201
# 3        2068178225
# 4        1506249360
#             ...
# 10861             0
# 10862             0
# 10863             0
# 10864             0
# 10865             0
# Name: Revenue, Length: 10866, dtype: int64

# %%
data['budget']
# Out:
# 0        150000000
# 1        150000000
# 2        110000000
# 3        200000000
# 4        190000000
#            ...
# 10861            0
# 10862            0
# 10863            0
# 10864            0
# 10865        19000
# Name: budget, Length: 10866, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
x = data['Revenue']
y = data['budget']

# %%
plt.plot(x,y)
plt.xlabel('Revenue')
plt.ylabel('budget')
plt.show()

# %%
# Continue to explore the data to address your additional research
#   questions. Add more headers as needed if you have more questions to
#   investigate.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# > **Tip**: Finally, summarize your findings and the results that have been performed. Make sure that you are clear with regards to the limitations of your exploration. If you haven't done any statistical tests, do not imply any statistical conclusions. And make sure you avoid implying causation from correlation!
#
# > **Tip**: Once you are satisfied with your work, you should save a copy of the report in HTML or PDF form via the **File** > **Download as** submenu. Before exporting your report, check over it to make sure that the flow of the report is complete. You should probably remove all of the "Tip" quotes like this one so that the presentation is as tidy as possible. Congratulations!
