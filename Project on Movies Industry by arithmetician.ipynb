# %% [markdown]
# > **Welcome Back !!!**: Welcome to the Exploratory Data Analysis project!
#
# # Project: Exploratory  of Data Analysis on Movies Industry by Adepoju Ibrahim
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('tmdb-movies.csv')

# %%
data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
data.rename(columns = {'original_title': 'title'})
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                               title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
data['id']
# Out:
# 0        135397
# 1         76341
# 2        262500
# 3        140607
# 4        168259
#           ...
# 10861        21
# 10862     20379
# 10863     39768
# 10864     21449
# 10865     22293
# Name: id, Length: 10866, dtype: int64

# %%
type(data["id"])
# Out:
# pandas.core.series.Series

# %%
data['imdb_id']
# Out:
# 0        tt0369610
# 1        tt1392190
# 2        tt2908446
# 3        tt2488496
# 4        tt2820852
#            ...
# 10861    tt0060371
# 10862    tt0060472
# 10863    tt0060161
# 10864    tt0061177
# 10865    tt0060666
# Name: imdb_id, Length: 10866, dtype: object

# %% [markdown]
# # Rename some columns

# %%
data.rename(columns = {'original_title': 'Title','cast':'Cast','budget':'Budget','revenue':'Revenue'},inplace = True)

# %%
data
# Out:
#            id    imdb_id  popularity     Budget     Revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                               Title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'Budget', 'Revenue', 'Title', 'Cast',
#        'homepage', 'director', 'tagline', 'keywords', 'overview', 'runtime',
#        'genres', 'production_companies', 'release_date', 'vote_count',
#        'vote_average', 'release_year', 'budget_adj', 'revenue_adj'],
#       dtype='object')

# %%
data.rename(columns = lambda x:x.strip().lower(), inplace = True)

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'title', 'cast',
#        'homepage', 'director', 'tagline', 'keywords', 'overview', 'runtime',
#        'genres', 'production_companies', 'release_date', 'vote_count',
#        'vote_average', 'release_year', 'budget_adj', 'revenue_adj'],
#       dtype='object')

# %%
data.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# title                    object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# title                      0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
data.drop(columns = 'homepage')
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                               title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
data.drop(columns = 'homepage', inplace = True)

# %%
data.shape
# Out:
# (10866, 20)

# %%
data.imdb_id.isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10861    False
# 10862    False
# 10863    False
# 10864    False
# 10865    False
# Name: imdb_id, Length: 10866, dtype: bool

# %%
data[data.imdb_id.isnull()]
# Out:
#           id imdb_id  popularity  budget  revenue  \
# 548   355131     NaN    0.108072       0        0
# 997   287663     NaN    0.330431       0        0
# 1528   15257     NaN    0.607851       0        0
# 1750  101907     NaN    0.256975       0        0
# 2401   45644     NaN    0.067753       0        0
# 4797  369145     NaN    0.167501       0        0
# 4872  269177     NaN    0.090552       0        0
# 6071  279954     NaN    0.004323     500        0
# 7527   50127     NaN    0.570337       0        0
# 7809   50128     NaN    0.060795       0        0
#
#                                                 title  \
# 548                        Sense8: Creating the World
# 997              Star Wars Rebels: Spark of Rebellion
# 1528                               Hulk vs. Wolverine
# 1750                                    Hulk vs. Thor
# 2401  Opeth: In Live Concert At The Royal Albert Hall
# 4797                          Doctor Who: The Snowmen
# ...

# %%
data.imdb_id.dropna()
# Out:
# 0        tt0369610
# 1        tt1392190
# 2        tt2908446
# 3        tt2488496
# 4        tt2820852
#            ...
# 10861    tt0060371
# 10862    tt0060472
# 10863    tt0060161
# 10864    tt0061177
# 10865    tt0060666
# Name: imdb_id, Length: 10856, dtype: object

# %%
data.imdb_id = data.imdb_id.dropna()

# %%
data = data[data.imdb_id.notnull()]

# %%
data.isnull().sum()
# Out:
# id                         0
# imdb_id                    0
# popularity                 0
# budget                     0
# revenue                    0
# title                      0
# cast                      76
# director                  40
# tagline                 2817
# keywords                1487
# overview                   3
# runtime                    0
# genres                    21
# production_companies    1025
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
# DATA ANALYSICAL QUESTIONS ON MY DATASET

# %% [markdown]
# # Q1:- is there any title for the new movies?

# %%
data.title.value_counts()
# Out:
# Hamlet                      4
# Oliver Twist                3
# Frankenstein                3
# A Christmas Carol           3
# Wuthering Heights           3
#                            ..
# The Veteran                 1
# African Cats                1
# Your Sister's Sister        1
# Elevator                    1
# Manos: The Hands of Fate    1
# Name: title, Length: 10561, dtype: int64

# %%
data.query('title in["African Cats","The Hands of Fate"]')
# Out:
#          id    imdb_id  popularity  budget   revenue         title  \
# 3638  57586  tt1223236    0.413573       0  15240456  African Cats
#
#                    cast                           director tagline  \
# 3638  Samuel L. Jackson  Keith Scholey|Alastair Fothergill     NaN
#
#                               keywords  \
# 3638  africa|cat|lion|lion cub|cheetah
#
#                                                overview  runtime  \
# 3638  African Cats captures the real-life love, humo...       89
#
#                             genres production_companies release_date  \
# 3638  Documentary|Family|Adventure         Disneynature      4/22/11
#
#       vote_count  vote_average  release_year  budget_adj   revenue_adj
# 3638          55           7.0          2011         0.0  1.477407e+07

# %%
data.title.unique()
# Out:
# array(['Jurassic World', 'Mad Max: Fury Road', 'Insurgent', ...,
#        'Beregis Avtomobilya', "What's Up, Tiger Lily?",
#        'Manos: The Hands of Fate'], dtype=object)

# %%
data.title.nunique()
# Out:
# 10561

# %%
data.query('title in["Hamlet","Frankenstein"]')
# Out:
#            id    imdb_id  popularity    budget    revenue         title  \
# 263    337029  tt4086032    0.473344         0          0  Frankenstein
# 1890    28238  tt1449175    0.086490         0          0        Hamlet
# 4240     3036  tt0109836    0.564501  45000000  112006296  Frankenstein
# 7230     3057  tt0368730    0.330795         0          0  Frankenstein
# 8573    10549  tt0116477    0.383469         0          0        Hamlet
# 8797    10688  tt0171359    0.277798   2000000    1568749        Hamlet
# 10106   10264  tt0099726    0.067973         0   20710451        Hamlet
#
#                                                     cast           director  \
# 263    Carrie-Anne Moss|Danny Huston|Xavier Samuel|To...       Bernard Rose
# 1890   David Tennant|Patrick Stewart|Penny Downie|Oli...      Gregory Doran
# 4240   Robert De Niro|Kenneth Branagh|Tom Hulce|Helen...    Kenneth Branagh
# 7230   Luke Goss|Alec Newman|Julie Delpy|William Hurt...       Kevin Connor
# ...

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'title', 'cast',
#        'director', 'tagline', 'keywords', 'overview', 'runtime', 'genres',
#        'production_companies', 'release_date', 'vote_count', 'vote_average',
#        'release_year', 'budget_adj', 'revenue_adj'],
#       dtype='object')

# %%
data.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# title                    object
# cast                     object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %% [markdown]
# # Q2:- is there a certain movies(horror,comendy) associated with high popularity?

# %%
data['popularity'].unique()
# Out:
# array([32.985763, 28.419936, 13.112507, ...,  0.065141,  0.064317,
#         0.035919])

# %%
data.groupby('release_year')['revenue_adj'].mean().sort_values(ascending = False).head(5).plot(kind = 'bar');
plt.yscale('log');

# %%
data.groupby('release_year')['revenue_adj'].mean().sort_values(ascending = True).head(6).plot(kind = 'bar');
plt.yscale('log');

# %%
data.groupby('release_year')['popularity'].mean().sort_values(ascending = False).head(5).plot(kind = 'bar');
plt.yscale('log');

# %%
data.groupby('release_year')['popularity'].mean().sort_values(ascending = True).head(7).plot(kind = 'bar');
plt.yscale('log');

# %%
data.groupby('release_year')['budget_adj'].mean().sort_values(ascending = True).head(5).plot(kind = 'bar');
plt.yscale('log');

# %%
data['popularity']
# Out:
# 0        32.985763
# 1        28.419936
# 2        13.112507
# 3        11.173104
# 4         9.335014
#            ...
# 10861     0.080598
# 10862     0.065543
# 10863     0.065141
# 10864     0.064317
# 10865     0.035919
# Name: popularity, Length: 10856, dtype: float64

# %%
data['popularity'].unique()
# Out:
# array([32.985763, 28.419936, 13.112507, ...,  0.065141,  0.064317,
#         0.035919])

# %%
data.query('genres in ["Horror","Comedy"]')[['title','popularity']].query('popularity == popularity.max()')
# Out:
#                        title  popularity
# 5230  Eddie Izzard: Glorious     6.66899

# %%
data.genres
# Out:
# 0        Action|Adventure|Science Fiction|Thriller
# 1        Action|Adventure|Science Fiction|Thriller
# 2               Adventure|Science Fiction|Thriller
# 3         Action|Adventure|Science Fiction|Fantasy
# 4                            Action|Crime|Thriller
#                            ...
# 10861                                  Documentary
# 10862                       Action|Adventure|Drama
# 10863                               Mystery|Comedy
# 10864                                Action|Comedy
# 10865                                       Horror
# Name: genres, Length: 10856, dtype: object

# %%
data.genres.unique()
# Out:
# array(['Action|Adventure|Science Fiction|Thriller',
#        'Adventure|Science Fiction|Thriller',
#        'Action|Adventure|Science Fiction|Fantasy', ...,
#        'Adventure|Drama|Action|Family|Foreign',
#        'Comedy|Family|Mystery|Romance',
#        'Mystery|Science Fiction|Thriller|Drama'], dtype=object)

# %%
data.genres.nunique()
# Out:
# 2037

# %%
#therefore the highest pupolarity associated with horror and comendy is "Eddie lzzard"

# %% [markdown]
# # who is the cast receives the height movies?

# %%
data['cast']
# Out:
# 0        Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1        Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2        Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3        Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4        Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#                                ...
# 10861    Michael Hynson|Robert August|Lord 'Tally Ho' B...
# 10862    James Garner|Eva Marie Saint|Yves Montand|Tosh...
# 10863    Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...
# 10864    Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...
# 10865    Harold P. Warren|Tom Neyman|John Reynolds|Dian...
# Name: cast, Length: 10856, dtype: object

# %%
data['cast'].describe()
# Out:
# count          10780
# unique         10710
# top       Louis C.K.
# freq               6
# Name: cast, dtype: object

# %%
data.drop(columns = 'cast')
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                               title            director  \
# 0                    Jurassic World     Colin Trevorrow
# 1                Mad Max: Fury Road       George Miller
# 2                         Insurgent    Robert Schwentke
# ...

# %%
data.groupby('cast')['budget'].mean()
# Out:
# cast
# "Weird Al" Yankovic|Victoria Jackson|Michael Richards|David Bowe|Fran Drescher                                    5000000.0
# 50 Cent|Forest Whitaker|Robert De Niro|Ryan O'Nan|Matt Gerald                                                    11000000.0
# 50 Cent|Joy Bryant|Adewale Akinnuoye-Agbaje|Omar Benson Miller|Terrence Howard                                   40000000.0
# 50 Cent|Ryan Phillippe|Bruce Willis|James Remar|Randy Couture                                                    20000000.0
# 50 Cent|Tamer Hassan|Danny Dyer|Blake Ritson|EsmÃ© Bianco                                                               0.0
#                                                                                                                     ...
# Ã“lafur Darri Ã“lafsson|JÃ³hann G. JÃ³hannsson|Thora Bjorg Helga|TheodÃ³r JÃºlÃ­usson|MarÃ­a SigurÃ°ardÃ³ttir     3000000.0
# ...

# %%
data.budget.mean()
# Out:
# 14639173.506724391

# %%
high = data.query('budget >= 1500000')

# %%
data.query('budget < 70000')
# Out:
#            id    imdb_id  popularity  budget   revenue  \
# 30     280996  tt3168230    3.927333       0  29355203
# 36     339527  tt1291570    3.358321       0  22354572
# 72     284289  tt2911668    2.272044       0     45895
# 74     347096  tt3478232    2.165433       0         0
# 75     308369  tt2582496    2.141506       0         0
# ...       ...        ...         ...     ...       ...
# 10861      21  tt0060371    0.080598       0         0
# 10862   20379  tt0060472    0.065543       0         0
# 10863   39768  tt0060161    0.065141       0         0
# 10864   21449  tt0061177    0.064317       0         0
# 10865   22293  tt0060666    0.035919   19000         0
#
#                                 title  \
# 30                         Mr. Holmes
# 36                             Solace
# 72                   Beyond the Reach
# 74             Mythica: The Darkspore
# 75     Me and Earl and the Dying Girl
# ...                               ...
# ...

# %%
data.query('budget < 70000')
# Out:
#            id    imdb_id  popularity  budget   revenue  \
# 30     280996  tt3168230    3.927333       0  29355203
# 36     339527  tt1291570    3.358321       0  22354572
# 72     284289  tt2911668    2.272044       0     45895
# 74     347096  tt3478232    2.165433       0         0
# 75     308369  tt2582496    2.141506       0         0
# ...       ...        ...         ...     ...       ...
# 10861      21  tt0060371    0.080598       0         0
# 10862   20379  tt0060472    0.065543       0         0
# 10863   39768  tt0060161    0.065141       0         0
# 10864   21449  tt0061177    0.064317       0         0
# 10865   22293  tt0060666    0.035919   19000         0
#
#                                 title  \
# 30                         Mr. Holmes
# 36                             Solace
# 72                   Beyond the Reach
# 74             Mythica: The Darkspore
# 75     Me and Earl and the Dying Girl
# ...                               ...
# ...

# %%
data.query('budget < 70000')
# Out:
#            id    imdb_id  popularity  budget   revenue  \
# 30     280996  tt3168230    3.927333       0  29355203
# 36     339527  tt1291570    3.358321       0  22354572
# 72     284289  tt2911668    2.272044       0     45895
# 74     347096  tt3478232    2.165433       0         0
# 75     308369  tt2582496    2.141506       0         0
# ...       ...        ...         ...     ...       ...
# 10861      21  tt0060371    0.080598       0         0
# 10862   20379  tt0060472    0.065543       0         0
# 10863   39768  tt0060161    0.065141       0         0
# 10864   21449  tt0061177    0.064317       0         0
# 10865   22293  tt0060666    0.035919   19000         0
#
#                                 title  \
# 30                         Mr. Holmes
# 36                             Solace
# 72                   Beyond the Reach
# 74             Mythica: The Darkspore
# 75     Me and Earl and the Dying Girl
# ...                               ...
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'title', 'cast',
#        'director', 'tagline', 'keywords', 'overview', 'runtime', 'genres',
#        'production_companies', 'release_date', 'vote_count', 'vote_average',
#        'release_year', 'budget_adj', 'revenue_adj'],
#       dtype='object')

# %% [markdown]
# #  which movie has the highest revenue?

# %%
data['revenue']
# Out:
# 0        1513528810
# 1         378436354
# 2         295238201
# 3        2068178225
# 4        1506249360
#             ...
# 10861             0
# 10862             0
# 10863             0
# 10864             0
# 10865             0
# Name: revenue, Length: 10856, dtype: int64

# %%
data['revenue'].describe()
# Out:
# count    1.085600e+04
# mean     3.986000e+07
# std      1.170511e+08
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.404690e+07
# max      2.781506e+09
# Name: revenue, dtype: float64

# %%
data.drop(columns = "revenue")
# Out:
#            id    imdb_id  popularity     budget                         title  \
# 0      135397  tt0369610   32.985763  150000000                Jurassic World
# 1       76341  tt1392190   28.419936  150000000            Mad Max: Fury Road
# 2      262500  tt2908446   13.112507  110000000                     Insurgent
# 3      140607  tt2488496   11.173104  200000000  Star Wars: The Force Awakens
# 4      168259  tt2820852    9.335014  190000000                     Furious 7
# ...       ...        ...         ...        ...                           ...
# 10861      21  tt0060371    0.080598          0            The Endless Summer
# 10862   20379  tt0060472    0.065543          0                    Grand Prix
# 10863   39768  tt0060161    0.065141          0           Beregis Avtomobilya
# 10864   21449  tt0061177    0.064317          0        What's Up, Tiger Lily?
# 10865   22293  tt0060666    0.035919      19000      Manos: The Hands of Fate
#
# ...

# %%
data.groupby('revenue')['budget'].mean()
# Out:
# revenue
# 0             2.582388e+06
# 2             6.000000e+06
# 3             6.666667e+04
# 5             7.500005e+06
# 6             1.570000e+07
#                   ...
# 1513528810    1.500000e+08
# 1519557910    2.200000e+08
# 1845034188    2.000000e+08
# 2068178225    2.000000e+08
# 2781505847    2.370000e+08
# Name: budget, Length: 4702, dtype: float64

# %%
data.groupby('revenue')['budget'].mean().sort_values(ascending = False).head(5).plot(kind = 'bar');
plt.yscale('log');

# %%
data.groupby('revenue')['popularity'].mean().sort_values(ascending = False).head(5).plot(kind = 'bar');
plt.yscale('log');

# %%
data.groupby('revenue')['revenue_adj'].mean().sort_values(ascending = True).head(5).plot(kind = 'bar');
plt.yscale('log');

# %% [markdown]
# # with what revenue has highest and lower budget?

# %%
data['budget']
# Out:
# 0        150000000
# 1        150000000
# 2        110000000
# 3        200000000
# 4        190000000
#            ...
# 10861            0
# 10862            0
# 10863            0
# 10864            0
# 10865        19000
# Name: budget, Length: 10856, dtype: int64

# %%
data['budget'].describe()
# Out:
# count    1.085600e+04
# mean     1.463917e+07
# std      3.092426e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.500000e+07
# max      4.250000e+08
# Name: budget, dtype: float64

# %%
data["budget"].mean()
# Out:
# 14639173.506724391

# %%
data.groupby('revenue')['budget'].mean()
# Out:
# revenue
# 0             2.582388e+06
# 2             6.000000e+06
# 3             6.666667e+04
# 5             7.500005e+06
# 6             1.570000e+07
#                   ...
# 1513528810    1.500000e+08
# 1519557910    2.200000e+08
# 1845034188    2.000000e+08
# 2068178225    2.000000e+08
# 2781505847    2.370000e+08
# Name: budget, Length: 4702, dtype: float64

# %%
data.budget.median()
# Out:
# 0.0

# %%
data.revenue.mean()
# Out:
# 39860003.02827929

# %%
data.revenue.median()
# Out:
# 0.0

# %%
data.query('budget >= 150000000')
# Out:
#           id    imdb_id  popularity     budget     revenue  \
# 0     135397  tt0369610   32.985763  150000000  1513528810
# 1      76341  tt1392190   28.419936  150000000   378436354
# 3     140607  tt2488496   11.173104  200000000  2068178225
# 4     168259  tt2820852    9.335014  190000000  1506249360
# 6      87101  tt1340138    8.654359  155000000   440603537
# ...      ...        ...         ...        ...         ...
# 7416    1267  tt0396555    1.672137  150000000   169332978
# 7436    2268  tt0385752    1.269498  180000000   372234864
# 7448    2698  tt0413099    1.109374  175000000   173000000
# 7474    1858  tt0418279    0.890557  150000000   709709780
# 8089    9804  tt0114898    1.232098  175000000   264218220
#
#                              title  \
# 0                   Jurassic World
# 1               Mad Max: Fury Road
# 3     Star Wars: The Force Awakens
# 4                        Furious 7
# 6               Terminator Genisys
# ...                            ...
# ...

# %%
data.query('budget < 150000000')
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 2      262500  tt2908446   13.112507  110000000   295238201
# 5      281957  tt1663202    9.110700  135000000   532950503
# 7      286217  tt3659388    7.667400  108000000   595380321
# 8      211672  tt2293640    7.404165   74000000  1156730962
# 12     264660  tt0470752    6.118847   15000000    36869414
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                           title  \
# 2                     Insurgent
# 5                  The Revenant
# 7                   The Martian
# 8                       Minions
# 12                   Ex Machina
# ...                         ...
# ...

# %%
high = data.query('budget >= 150000000')

# %%
low = data.query('budget < 150000000')

# %%
bin_edges = [110000000,150000000]
bin_names = [low,high]
#data['budget'] = pd.cut(data['budget'],bin_edges, labels = bin_names)

# %%
#data['budget'] = pd.cut(data['budget'],bin_edges,labels = bin_names)

# %% [markdown]
# # Who is the most active cast ?

# %%
data['cast']
# Out:
# 0        Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1        Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2        Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3        Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4        Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#                                ...
# 10861    Michael Hynson|Robert August|Lord 'Tally Ho' B...
# 10862    James Garner|Eva Marie Saint|Yves Montand|Tosh...
# 10863    Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...
# 10864    Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...
# 10865    Harold P. Warren|Tom Neyman|John Reynolds|Dian...
# Name: cast, Length: 10856, dtype: object

# %%
data['cast'].describe()
# Out:
# count          10780
# unique         10710
# top       Louis C.K.
# freq               6
# Name: cast, dtype: object

# %%
# I analyse my dataset based on people choice and questions

# %%
# I use pandas,numpy,seaborn and matpolitlib modulus to execuate my project and very easy for me.

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# > **Completed**

# %%
# the data have been cleared and well prepared !!!

# %%
# i Use this cell to set up import statements for all of the packages that you
#   plan to use.

# Remember to include a 'magic word' so that your visualizations are plotted
#   inline with the notebook. See this page for more:
#   http://ipython.readthedocs.io/en/stable/interactive/magics.html

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# > **Tip**: In this section of the report, i will load in the data, check for cleanliness, and then trim and clean your dataset for analysis. i sure that the document is steps carefully and i justify my cleaning decisions.
#
# ### General Properties

# %%
data
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                               title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
pd.concat([data.runtime,data.release_year],axis = 0)
# Out:
# 0         124
# 1         120
# 2         119
# 3         136
# 4         137
#          ...
# 10861    1966
# 10862    1966
# 10863    1966
# 10864    1966
# 10865    1966
# Length: 21712, dtype: int64

# %%
data['runtime']
# Out:
# 0        124
# 1        120
# 2        119
# 3        136
# 4        137
#         ...
# 10861     95
# 10862    176
# 10863     94
# 10864     80
# 10865     74
# Name: runtime, Length: 10856, dtype: int64

# %%
data['release_year']
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 10861    1966
# 10862    1966
# 10863    1966
# 10864    1966
# 10865    1966
# Name: release_year, Length: 10856, dtype: int64

# %%
pd.concat([data.runtime,data.release_year],axis = 1)
# Out:
#        runtime  release_year
# 0          124          2015
# 1          120          2015
# 2          119          2015
# 3          136          2015
# 4          137          2015
# ...        ...           ...
# 10861       95          1966
# 10862      176          1966
# 10863       94          1966
# 10864       80          1966
# 10865       74          1966
#
# [10856 rows x 2 columns]

# %%
M_d = pd.concat([data.runtime,data.release_year],axis = 1)

# %%
M_d
# Out:
#        runtime  release_year
# 0          124          2015
# 1          120          2015
# 2          119          2015
# 3          136          2015
# 4          137          2015
# ...        ...           ...
# 10861       95          1966
# 10862      176          1966
# 10863       94          1966
# 10864       80          1966
# 10865       74          1966
#
# [10856 rows x 2 columns]

# %%
M_d.mean()
# Out:
# runtime          102.104274
# release_year    2001.313928
# dtype: float64

# %%
M_d.to_csv('m_d.csv',index = False)

# %%
import pandas as pd
import numpy as np

# %%
m_d = pd.read_csv('m_d.csv')

# %%
m_d.head()
# Out:
#    runtime  release_year
# 0      124          2015
# 1      120          2015
# 2      119          2015
# 3      136          2015
# 4      137          2015

# %%
data['id']
# Out:
# 0        135397
# 1         76341
# 2        262500
# 3        140607
# 4        168259
#           ...
# 10861        21
# 10862     20379
# 10863     39768
# 10864     21449
# 10865     22293
# Name: id, Length: 10856, dtype: int64

# %%
data['revenue']
# Out:
# 0        1513528810
# 1         378436354
# 2         295238201
# 3        2068178225
# 4        1506249360
#             ...
# 10861             0
# 10862             0
# 10863             0
# 10864             0
# 10865             0
# Name: revenue, Length: 10856, dtype: int64

# %%
data['budget']
# Out:
# 0        150000000
# 1        150000000
# 2        110000000
# 3        200000000
# 4        190000000
#            ...
# 10861            0
# 10862            0
# 10863            0
# 10864            0
# 10865        19000
# Name: budget, Length: 10856, dtype: int64

# %%
mas = pd.concat([data.budget,data.revenue],axis = 1)

# %%
mas
# Out:
#           budget     revenue
# 0      150000000  1513528810
# 1      150000000   378436354
# 2      110000000   295238201
# 3      200000000  2068178225
# 4      190000000  1506249360
# ...          ...         ...
# 10861          0           0
# 10862          0           0
# 10863          0           0
# 10864          0           0
# 10865      19000           0
#
# [10856 rows x 2 columns]

# %%
mas.to_csv('mas_d.csv',index = False)

# %%
df = pd.read_csv('mas_d.csv')

# %%
df.head()
# Out:
#       budget     revenue
# 0  150000000  1513528810
# 1  150000000   378436354
# 2  110000000   295238201
# 3  200000000  2068178225
# 4  190000000  1506249360

# %%
M_d.shape[0]
# Out:
# 10856

# %%
df.shape[0]
# Out:
# 10856

# %%
pd.concat([m_d,mas],axis = 0)
# Out:
#        runtime  release_year   budget  revenue
# 0        124.0        2015.0      NaN      NaN
# 1        120.0        2015.0      NaN      NaN
# 2        119.0        2015.0      NaN      NaN
# 3        136.0        2015.0      NaN      NaN
# 4        137.0        2015.0      NaN      NaN
# ...        ...           ...      ...      ...
# 10861      NaN           NaN      0.0      0.0
# 10862      NaN           NaN      0.0      0.0
# 10863      NaN           NaN      0.0      0.0
# 10864      NaN           NaN      0.0      0.0
# 10865      NaN           NaN  19000.0      0.0
#
# [21712 rows x 4 columns]

# %%
d_f = pd.concat([M_d,mas],axis = 0)

# %%
#I print out Data.csv and ade.csv was extracted from my main data frame to be explorary in the next frame of my project.

# %%
# I Load my data and print out a few lines. Perform operations to inspect data
#  i checked types and look for instances of missing or possibly errant data.

# %% [markdown]
# > **completed**: I don't _ perform too many operations in each cell. I Create cells freely to explore my data. i choose that i can take with this project is to do a lot of explorations in an initial notebook. These don't have to be organized, but i make sure you use enough comments to understand the purpose of each code cell. Then, and after i done with my analysis, i create a duplicate notebook where i will trims the excess and organize my steps so that i have a flowing, cohesive report.
#
#
# ## A well prepared data !!!

# %%
# data 1

M_d
# Out:
#           budget     revenue
# 0      150000000  1513528810
# 1      150000000   378436354
# 2      110000000   295238201
# 3      200000000  2068178225
# 4      190000000  1506249360
# ...          ...         ...
# 10861          0           0
# 10862          0           0
# 10863          0           0
# 10864          0           0
# 10865      19000           0
#
# [10856 rows x 2 columns]

# %%
# data 2

mas
# Out:
#           budget     revenue
# 0      150000000  1513528810
# 1      150000000   378436354
# 2      110000000   295238201
# 3      200000000  2068178225
# 4      190000000  1506249360
# ...          ...         ...
# 10861          0           0
# 10862          0           0
# 10863          0           0
# 10864          0           0
# 10865      19000           0
#
# [10856 rows x 2 columns]

# %%
# data three

m_d
# Out:
#        runtime  release_year
# 0          124          2015
# 1          120          2015
# 2          119          2015
# 3          136          2015
# 4          137          2015
# ...        ...           ...
# 10851       95          1966
# 10852      176          1966
# 10853       94          1966
# 10854       80          1966
# 10855       74          1966
#
# [10856 rows x 2 columns]

# %%
m_d.shape[0]
# Out:
# 10856

# %%
m_d.describe()
# Out:
#             runtime  release_year
# count  10856.000000  10856.000000
# mean     102.104274   2001.313928
# std       31.347440     12.815353
# min        0.000000   1960.000000
# 25%       90.000000   1995.000000
# 50%       99.000000   2006.000000
# 75%      111.000000   2011.000000
# max      900.000000   2015.000000

# %%
m_d.mean()
# Out:
# runtime          102.104274
# release_year    2001.313928
# dtype: float64

# %%
m_d.median()
# Out:
# runtime           99.0
# release_year    2006.0
# dtype: float64

# %%
m_d.max()
# Out:
# runtime          900
# release_year    2015
# dtype: int64

# %%
m_d.min()
# Out:
# runtime            0
# release_year    1960
# dtype: int64

# %%
m_d.max().describe()
# Out:
# count       2.000000
# mean     1457.500000
# std       788.424061
# min       900.000000
# 25%      1178.750000
# 50%      1457.500000
# 75%      1736.250000
# max      2015.000000
# dtype: float64

# %%
mas.max()
# Out:
# budget      425000000
# revenue    2781505847
# dtype: int64

# %%
m_d.dtypes
# Out:
# runtime         int64
# release_year    int64
# dtype: object

# %%
mas.dtypes
# Out:
# budget     int64
# revenue    int64
# dtype: object

# %%
mas.median()
# Out:
# budget     0.0
# revenue    0.0
# dtype: float64

# %%
mas.median().describe()
# Out:
# count    2.0
# mean     0.0
# std      0.0
# min      0.0
# 25%      0.0
# 50%      0.0
# 75%      0.0
# max      0.0
# dtype: float64

# %%
m_d
# Out:
#        runtime  release_year
# 0          124          2015
# 1          120          2015
# 2          119          2015
# 3          136          2015
# 4          137          2015
# ...        ...           ...
# 10851       95          1966
# 10852      176          1966
# 10853       94          1966
# 10854       80          1966
# 10855       74          1966
#
# [10856 rows x 2 columns]

# %%
m_d['runtime'].dtypes
# Out:
# dtype('int64')

# %%
m_d['release_year'].dtypes
# Out:
# dtype('int64')

# %%
#my data has been well prepared as cleand

# %%
#  After discussing the structure of the data and any problems that need to be cleaned, perform those cleaning steps in the second part of this section.

# %% [markdown]
# # <a id='eda'></a>
# ## Exploratory Data Analysis
#
# > **Tip**: Now that you've trimmed and cleaned your data, you're ready to move on to exploration. Compute statistics and create visualizations with the goal of addressing the research questions that you posed in the Introduction section. It is recommended that you be systematic with your approach. Look at one variable at a time, and then follow it up by looking at relationships between variables.
#
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
m_d['runtime']
# Out:
# 0        124
# 1        120
# 2        119
# 3        136
# 4        137
#         ...
# 10851     95
# 10852    176
# 10853     94
# 10854     80
# 10855     74
# Name: runtime, Length: 10856, dtype: int64

# %%
m_d.head().plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.histplot(data = m_d.head()['runtime'])
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='Count'>

# %% [markdown]
# # chart

# %%
mas['budget']
# Out:
# 0        150000000
# 1        150000000
# 2        110000000
# 3        200000000
# 4        190000000
#            ...
# 10861            0
# 10862            0
# 10863            0
# 10864            0
# 10865        19000
# Name: budget, Length: 10856, dtype: int64

# %%
mas['revenue']
# Out:
# 0        1513528810
# 1         378436354
# 2         295238201
# 3        2068178225
# 4        1506249360
#             ...
# 10861             0
# 10862             0
# 10863             0
# 10864             0
# 10865             0
# Name: revenue, Length: 10856, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
x = mas['budget']
y = mas['revenue']

# %%
plt.plot(x,y)
plt.xlabel('budget')
plt.ylabel('revenue')
plt.show()

# %%
x = m_d['release_year']
y = m_d['runtime']

# %%
plt.plot(x,y)
plt.xlabel('release_year')
plt.ylabel('runtime')
plt.show()

# %%
data
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                               title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
data.groupby('revenue')['budget'].mean().sort_values(ascending = False).head(5).plot(kind = 'hist');
plt.yscale('log');

# %%
x = m_d['release_year']
y = m_d['runtime']
plt.bar(x,y)
plt.xlabel('release_year')
plt.ylabel('runtime')
plt.show()

# %%
x = m_d['release_year']
y = mas['budget']

# %%
plt.bar(x,y)
plt.xlabel('release_year')
plt.ylabel('budget')
plt.show()

# %%
# i Continue to explore the data to address my additional research
#   questions. Add more headers as needed if you have more questions to
#   investigate.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# > **Completed**: Finally, I summarize my findings and the results that have been performed. I Make sure that I are clear with regards to the limitations of my exploration. I haven't done any statistical tests, so,i do not imply any statistical my conclusions. And i  make sure i avoid implying causation from correlation!

# %% [markdown]
# #  Aspiring Arithmetician Adepoju
